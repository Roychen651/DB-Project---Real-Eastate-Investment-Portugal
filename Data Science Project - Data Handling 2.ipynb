# %% [markdown]
# <font face="Lucida Handwriting
# " size=6 color='#CDB79E'> Libraries import <font>

# %%
import pandas as pd
import numpy as np
import requests
import json
import re
from bs4 import BeautifulSoup

# %% [markdown]
# <font face="Lucida Handwriting
# " size=6 color='#CDB79E'> Data Handling(proprties to buy)<font>

# %%
df = pd.read_csv("Real_estate_data_Portugal.csv",index_col = 0)

# %%
# Check if there are missing values in the DataFrame
df.isnull().sum()
# Out:
# Address       0
# Prop_type    60
# Size          0
# Bath          0
# Bed           0
# dtype: int64

# %%
# show all the types of the details and the size of the table ( rows X cols ) , *before data handling

df_handling = pd.read_csv('Real_estate_data_Portugal.csv', header=0, sep=',') 
print('Real Estate columns:', df_handling.columns)
print('Real Estate dtypes:', df_handling.dtypes)
print('Real Estate shape:', df_handling.shape)
df_handling.head()
# Out:
# Real Estate columns: Index(['Price', 'Address', 'Prop_type', 'Size', 'Bath', 'Bed'], dtype='object')
# Real Estate dtypes: Price        object
# Address      object
# Prop_type    object
# Size         object
# Bath         object
# Bed          object
# dtype: object
# Real Estate shape: (11340, 6)
#          Price                                            Address Prop_type  \
# 0   350 000 €                   Porto -   Maia, Castêlo da Maia       House
# 1    98 000 €                        Porto -   Paredes, Lordelo       House
# 2   300 000 €    Porto -   Felgueiras, Vila Fria e Vizela (São...     House
# 3   199 900 €                        Porto -   Amarante, Telões       House
# 4   235 000 €             Porto -   Marco de Canaveses, Tabuado       House
#
#         Size Bath Bed
# 0    233 m2     4   4
# 1     60 m2     1   2
# 2    642 m2     3   4
# 3    188 m2     3   3
# 4    200 m2     2   3

# %%
# steps to convert str to int or float, first remove unnecessary characters
# split from the Address the division and the city to new columns.

df_handling['Price'] = df_handling['Price'].str.replace(' ', '')
df_handling['Price'] = df_handling['Price'].str.replace('€', '')
df_handling['Address'] = df_handling['Address'].str.replace('Porto ', '')
df_handling['Address'] = df_handling['Address'].str.replace('Lisbon ', '')
df_handling['Address'] = df_handling['Address'].str.replace('Braga ', '')
df_handling['Address'] = df_handling['Address'].str.replace('-', '')
df_handling['City'] = df_handling['Address'].str.split(',', expand=True)[0]
df_handling['Division'] = df_handling['Address'].str.split(',', expand=True)[1]
df_handling['City'] = df_handling['City'].str.strip()  # removing leading and tailing white spaces
df_handling['Size'] = df_handling['Size'].str.replace('m2', '')


# delete the Address column 

df_handling.drop('Address', inplace=True, axis=1)

# %%
df_handling.head()
# Out:
#     Price Prop_type     Size Bath Bed                City  \
# 0  350000     House    233      4   4                Maia
# 1   98000     House     60      1   2             Paredes
# 2  300000     House    642      3   4          Felgueiras
# 3  199900     House    188      3   3            Amarante
# 4  235000     House    200      2   3  Marco de Canaveses
#
#                             Division
# 0                  Castêlo da Maia
# 1                          Lordelo
# 2   Vila Fria e Vizela (São Jorge)
# 3                           Telões
# 4                          Tabuado

# %%
# convert to int/float

df_handling['Price'] = pd.to_numeric(df_handling['Price'], errors='coerce')
df_handling['Size'] = pd.to_numeric(df_handling['Size'], errors='coerce')
df_handling['Bath'] = pd.to_numeric(df_handling['Bath'], errors='coerce')
df_handling['Bed'] = pd.to_numeric(df_handling['Bed'], errors='coerce')



print(df_handling.dtypes)
# Out:
# Price        float64
# Prop_type     object
# Size         float64
# Bath         float64
# Bed          float64
# City          object
# Division      object
# dtype: object

# %%
df_handling.to_csv(r'df_after_handling.csv', index = False, header=True)

# %%
df1 = pd.read_csv("df_after_handling.csv",index_col = 0)

# %% [markdown]
# <font face="Lucida Handwriting
# " size=6 color='#CDB79E'> Duplication and
#     data types handling  <font>

# %%
df1
# Out:
#                 Prop_type    Size  Bath  Bed                City  \
# Price
# 350000.0            House   233.0   4.0  4.0                Maia
# 98000.0             House    60.0   1.0  2.0             Paredes
# 300000.0            House   642.0   3.0  4.0          Felgueiras
# 199900.0            House   188.0   3.0  3.0            Amarante
# 235000.0            House   200.0   2.0  3.0  Marco de Canaveses
# ...                   ...     ...   ...  ...                 ...
# 800000.0  Condo/Apartment   227.0   3.0  3.0    Lisboa    Sintra
# 750000.0  Condo/Apartment   207.0   2.0  4.0     Lisboa    Mafra
# 800000.0  Condo/Apartment   201.0   2.0  3.0    Lisboa    Lisboa
# 640000.0  Condo/Apartment   153.0   2.0  2.0    Lisboa    Sintra
# 500000.0  Condo/Apartment  4422.0   3.0  4.0    Lisboa    Loures
#
#                                    Division
# Price
# 350000.0                  Castêlo da Maia
# 98000.0                           Lordelo
# 300000.0   Vila Fria e Vizela (São Jorge)
# 199900.0                           Telões
# 235000.0                          Tabuado
# ...                                     ...
# 800000.0                   Queluz e Belas
# 750000.0                         Ericeira
# 800000.0                           Lumiar
# 640000.0                   Queluz e Belas
# 500000.0                           Loures
#
# [11340 rows x 6 columns]

# %%
def count_duplicatives(df, col_name=None):
    if(col_name ==None):
        return df.duplicated().sum()
    
    return df.duplicated([col_name]).sum()

# %%
df1 = df_handling.dropna(axis=0).copy()

# %%
df1.isnull().sum()
# Out:
# Price        0
# Prop_type    0
# Size         0
# Bath         0
# Bed          0
# City         0
# Division     0
# dtype: int64

# %%
df1
# Out:
#           Price        Prop_type    Size  Bath  Bed                City  \
# 0      350000.0            House   233.0   4.0  4.0                Maia
# 1       98000.0            House    60.0   1.0  2.0             Paredes
# 2      300000.0            House   642.0   3.0  4.0          Felgueiras
# 3      199900.0            House   188.0   3.0  3.0            Amarante
# 4      235000.0            House   200.0   2.0  3.0  Marco de Canaveses
# ...         ...              ...     ...   ...  ...                 ...
# 11335  800000.0  Condo/Apartment   227.0   3.0  3.0    Lisboa    Sintra
# 11336  750000.0  Condo/Apartment   207.0   2.0  4.0     Lisboa    Mafra
# 11337  800000.0  Condo/Apartment   201.0   2.0  3.0    Lisboa    Lisboa
# 11338  640000.0  Condo/Apartment   153.0   2.0  2.0    Lisboa    Sintra
# 11339  500000.0  Condo/Apartment  4422.0   3.0  4.0    Lisboa    Loures
#
#                                 Division
# 0                      Castêlo da Maia
# 1                              Lordelo
# 2       Vila Fria e Vizela (São Jorge)
# 3                               Telões
# 4                              Tabuado
# ...                                  ...
# 11335                   Queluz e Belas
# 11336                         Ericeira
# 11337                           Lumiar
# 11338                   Queluz e Belas
# 11339                           Loures
#
# [11280 rows x 7 columns]

# %%
df1.dtypes
# Out:
# Price        float64
# Prop_type     object
# Size         float64
# Bath         float64
# Bed          float64
# City          object
# Division      object
# dtype: object

# %%
# backup our data frame , copy to new one , 
# and change the prop type col to type category

df2 = df1.copy()
df2["Prop_type"]= df2["Prop_type"].astype('category')
df2.dtypes
# Out:
# Price         float64
# Prop_type    category
# Size          float64
# Bath          float64
# Bed           float64
# City           object
# Division       object
# dtype: object

# %%
# Convert categorical variable to a number
# origin of the funcion : our course in the campus website L05-NB04-Conversions
replace_map={'House':1,'Condo/Apartment':2}
df2.replace(replace_map, inplace=True)

# another fixing of the data
df2['City'] = df2['City'].str.replace('Lisboa ', '')

df2
# Out:
#           Price Prop_type    Size  Bath  Bed                City  \
# 0      350000.0         1   233.0   4.0  4.0                Maia
# 1       98000.0         1    60.0   1.0  2.0             Paredes
# 2      300000.0         1   642.0   3.0  4.0          Felgueiras
# 3      199900.0         1   188.0   3.0  3.0            Amarante
# 4      235000.0         1   200.0   2.0  3.0  Marco de Canaveses
# ...         ...       ...     ...   ...  ...                 ...
# 11335  800000.0         2   227.0   3.0  3.0              Sintra
# 11336  750000.0         2   207.0   2.0  4.0               Mafra
# 11337  800000.0         2   201.0   2.0  3.0              Lisboa
# 11338  640000.0         2   153.0   2.0  2.0              Sintra
# 11339  500000.0         2  4422.0   3.0  4.0              Loures
#
#                                 Division
# 0                      Castêlo da Maia
# 1                              Lordelo
# 2       Vila Fria e Vizela (São Jorge)
# 3                               Telões
# 4                              Tabuado
# ...                                  ...
# 11335                   Queluz e Belas
# 11336                         Ericeira
# 11337                           Lumiar
# 11338                   Queluz e Belas
# 11339                           Loures
#
# [11280 rows x 7 columns]

# %% [markdown]
# <font face="Lucida Handwriting
# " size=6 color='#CDB79E'> Saving the result to csv file <font>

# %%
df2.to_csv(r'dataf_final.csv', index = False, header=True)

# %% [markdown]
# <font face="Lucida Handwriting
# " size=5 color='#CDB79E'> Data Handling (properties to rent) <font>

# %%
rent_lisboa = pd.read_csv('lisboa_district_rent.csv')
porto_lisboa = pd.read_csv('porto_district_rent.csv')
braga_lisboa = pd.read_csv('braga_district_rent.csv')

# %%
frames_rent = [rent_lisboa, porto_lisboa,braga_lisboa]
df_only_rent = pd.concat(frames_rent)
df_only_rent.to_csv(r'only_rent.csv', index = False, header=True) #saving as csv

# %%
# show all the types of the details and the size of the table ( rows X cols ) , *before data handling

df_rent = pd.read_csv('only_rent.csv', header=0, sep=',') 
print('columns:', df_rent.columns)
print('dtypes:', df_rent.dtypes)
print('shape:', df_rent.shape)
df_rent.head()
# Out:
# columns: Index(['Price', 'Address', 'Prop_type', 'Size', 'Bath', 'Bed'], dtype='object')
# dtypes: Price        object
# Address      object
# Prop_type    object
# Size         object
# Bath          int64
# Bed          object
# dtype: object
# shape: (1440, 6)
#                     Price                                      Address  \
# 0     950 €  /  Monthly        Lisboa -   Cascais, Cascais e Estoril
# 1   1 900 €  /  Monthly     Lisboa -   Cascais, São Domingos de Rana
# 2   1 900 €  /  Monthly     Lisboa -   Cascais, São Domingos de Rana
# 3     850 €  /  Monthly                   Lisboa -   Lisboa, Olivais
# 4   2 350 €  /  Monthly                   Lisboa -   Lisboa, Arroios
#
#          Prop_type       Size  Bath   Bed
# 0  Condo/Apartment     57 m2      1    1
# 1  Condo/Apartment    139 m2      2    3
# 2  Condo/Apartment    139 m2      2    3
# 3  Condo/Apartment     55 m2      1    2
# 4  Condo/Apartment    112 m2      2    2

# %%
df_rent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1440 non-null   object
#  1   Address    1440 non-null   object
#  2   Prop_type  1440 non-null   object
#  3   Size       1440 non-null   object
#  4   Bath       1440 non-null   int64
#  5   Bed        1440 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 67.6+ KB

# %%
# steps to convert str to int or float, first remove unnecessary characters
# split from the Address the division and the city to new columns.

df_rent['Price'] = df_rent['Price'].str.replace(' ', '')
df_rent[['Price', 'Term']] = df_rent['Price'].str.split(pat='€', expand=True)
df_rent['Address'] = df_rent['Address'].str.replace('Lisboa ', '')
df_rent['Address'] = df_rent['Address'].str.replace('Porto ', '')
df_rent['Address'] = df_rent['Address'].str.replace('Braga ', '')
df_rent['Address'] = df_rent['Address'].str.replace('-', '')
df_rent['City'] = df_rent['Address'].str.split(',', expand=True)[0]
df_rent['Division'] = df_rent['Address'].str.split(',', expand=True)[1]
df_rent['City'] = df_rent['City'].str.strip()  # removing leading and tailing white spaces
df_rent['Size'] = df_rent['Size'].str.replace('m2', '')


# delete the Address column 

df_rent.drop('Address', inplace=True, axis=1)

# %%
df_rent.head()
# Out:
#   Price        Prop_type     Size  Bath   Bed       Term     City  \
# 0   950  Condo/Apartment     57       1    1   / Monthly  Cascais
# 1  1900  Condo/Apartment    139       2    3   / Monthly  Cascais
# 2  1900  Condo/Apartment    139       2    3   / Monthly  Cascais
# 3   850  Condo/Apartment     55       1    2   / Monthly   Lisboa
# 4  2350  Condo/Apartment    112       2    2   / Monthly   Lisboa
#
#                   Division
# 0      Cascais e Estoril
# 1   São Domingos de Rana
# 2   São Domingos de Rana
# 3                Olivais
# 4                Arroios

# %%
# convert to int/float


df_rent['Price'] = pd.to_numeric(df_rent['Price'], errors='coerce')
df_rent['Size'] = pd.to_numeric(df_rent['Size'], errors='coerce')
df_rent['Bath'] = pd.to_numeric(df_rent['Bath'], errors='coerce')
df_rent['Bed'] = pd.to_numeric(df_rent['Bed'], errors='coerce')

print(df_rent.dtypes)
# Out:
# Price          int64
# Prop_type     object
# Size           int64
# Bath           int64
# Bed          float64
# Term          object
# City          object
# Division      object
# dtype: object

# %%
df_rent.head()
# Out:
#    Price        Prop_type  Size  Bath  Bed       Term     City  \
# 0    950  Condo/Apartment    57     1  1.0  / Monthly  Cascais
# 1   1900  Condo/Apartment   139     2  3.0  / Monthly  Cascais
# 2   1900  Condo/Apartment   139     2  3.0  / Monthly  Cascais
# 3    850  Condo/Apartment    55     1  2.0  / Monthly   Lisboa
# 4   2350  Condo/Apartment   112     2  2.0  / Monthly   Lisboa
#
#                   Division
# 0      Cascais e Estoril
# 1   São Domingos de Rana
# 2   São Domingos de Rana
# 3                Olivais
# 4                Arroios

# %% [markdown]
# <font face="Lucida Handwriting
# " size=6 color='#CDB79E'> Duplication and
#     data types handling  <font>

# %%
df_rent
# Out:
#       Price        Prop_type  Size  Bath  Bed       Term               City  \
# 0       950  Condo/Apartment    57     1  1.0  / Monthly            Cascais
# 1      1900  Condo/Apartment   139     2  3.0  / Monthly            Cascais
# 2      1900  Condo/Apartment   139     2  3.0  / Monthly            Cascais
# 3       850  Condo/Apartment    55     1  2.0  / Monthly             Lisboa
# 4      2350  Condo/Apartment   112     2  2.0  / Monthly             Lisboa
# ...     ...              ...   ...   ...  ...        ...                ...
# 1435    200  Business Office    55     1  NaN  / Monthly  Celorico de Basto
# 1436    350  Business Office    75     1  NaN  / Monthly  Celorico de Basto
# 1437    300  Business Office    75     1  NaN  / Monthly  Celorico de Basto
# 1438    600            Store   119     0  NaN  / Monthly              Braga
# 1439    750  Condo/Apartment    79     0  2.0  / Monthly         Vila Verde
#
#                      Division
# 0         Cascais e Estoril
# 1      São Domingos de Rana
# 2      São Domingos de Rana
# 3                   Olivais
# 4                   Arroios
# ...                       ...
# 1435                  Britelo
# 1436                  Britelo
# 1437                  Britelo
# 1438             São Victor
# 1439   Vila Verde e Barbudo
#
# [1440 rows x 8 columns]

# %%
# finding row that's missing Bed data
df_rent[df_rent['Bed'].isnull()]
# Out:
#       Price            Prop_type  Size  Bath  Bed       Term  \
# 7      4900                Store   539     0  NaN  / Monthly
# 10      900                Store    50     1  NaN  / Monthly
# 14     1500                Store   180     0  NaN  / Monthly
# 16      900  Others - Commercial    30     2  NaN  / Monthly
# 17     5500                Store   110     0  NaN  / Monthly
# ...     ...                  ...   ...   ...  ...        ...
# 1434    200      Business Office    55     1  NaN  / Monthly
# 1435    200      Business Office    55     1  NaN  / Monthly
# 1436    350      Business Office    75     1  NaN  / Monthly
# 1437    300      Business Office    75     1  NaN  / Monthly
# 1438    600                Store   119     0  NaN  / Monthly
#
#                    City                                 Division
# 7                Loures                  Sacavém e Prior Velho
# 10               Lisboa                        Penha de França
# 14             Odivelas   Póvoa de Santo Adrião e Olival Basto
# 16               Sintra                 Massamá e Monte Abraão
# 17               Lisboa                       Campo de Ourique
# ...                 ...                                      ...
# 1434  Celorico de Basto                                  Britelo
# 1435  Celorico de Basto                                  Britelo
# 1436  Celorico de Basto                                  Britelo
# 1437  Celorico de Basto                                  Britelo
# 1438              Braga                             São Victor
#
# [430 rows x 8 columns]

# %%
df_rent = df_rent.dropna(subset = ['Bed'])

# %%
# finding row that's missing Bed data
df_rent[df_rent['Bed'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Price, Prop_type, Size, Bath, Bed, Term, City, Division]
# Index: []

# %%
# bed and bath being zero
print(df_rent['Bath'].value_counts()[0])
print(df_rent['Bed'].value_counts()[0])
df_rent1 = df_rent.copy()
df_rent1.head()
# Out:
# 35
# 86
#    Price        Prop_type  Size  Bath  Bed       Term     City  \
# 0    950  Condo/Apartment    57     1  1.0  / Monthly  Cascais
# 1   1900  Condo/Apartment   139     2  3.0  / Monthly  Cascais
# 2   1900  Condo/Apartment   139     2  3.0  / Monthly  Cascais
# 3    850  Condo/Apartment    55     1  2.0  / Monthly   Lisboa
# 4   2350  Condo/Apartment   112     2  2.0  / Monthly   Lisboa
#
#                   Division
# 0      Cascais e Estoril
# 1   São Domingos de Rana
# 2   São Domingos de Rana
# 3                Olivais
# 4                Arroios

# %%
# 120 rows are not significant, so drop all
df_rent1.drop(df_rent1[(df_rent1.Bath ==0) | (df_rent1.Bed ==0)].index, inplace=True)
df_rent1.describe()
# Out:
#              Price        Size        Bath         Bed
# count   906.000000  906.000000  906.000000  906.000000
# mean   1593.460265  103.374172    1.812362    2.246137
# std    1182.380022   62.497966    1.039603    1.211415
# min     350.000000   44.000000    1.000000    1.000000
# 25%     850.000000   57.000000    1.000000    1.000000
# 50%    1250.000000   87.000000    2.000000    2.000000
# 75%    1900.000000  133.500000    2.000000    3.000000
# max    6000.000000  347.000000    5.000000    6.000000

# %%
df_rent1.isnull().sum()
# Out:
# Price        0
# Prop_type    0
# Size         0
# Bath         0
# Bed          0
# Term         0
# City         0
# Division     0
# dtype: int64

# %%
# backup our data frame , copy to new one , 
# and change the prop type col to type category

df_rent2 = df_rent1.copy()
df_rent2["Prop_type"]= df_rent2["Prop_type"].astype('category')
df_rent2.dtypes
# Out:
# Price           int64
# Prop_type    category
# Size            int64
# Bath            int64
# Bed           float64
# Term           object
# City           object
# Division       object
# dtype: object

# %%
# Convert categorical variable to a number
# origin of the funcion : our course in the campus website L05-NB04-Conversions
replace_map={'House':1,'Condo/Apartment':2}
df_rent2.replace(replace_map, inplace=True)

df_rent2
# Out:
#       Price Prop_type  Size  Bath  Bed       Term              City  \
# 0       950         2    57     1  1.0  / Monthly           Cascais
# 1      1900         2   139     2  3.0  / Monthly           Cascais
# 2      1900         2   139     2  3.0  / Monthly           Cascais
# 3       850         2    55     1  2.0  / Monthly            Lisboa
# 4      2350         2   112     2  2.0  / Monthly            Lisboa
# ...     ...       ...   ...   ...  ...        ...               ...
# 1428    825         2    94     2  2.0  / Monthly             Braga
# 1429    350         1   100     1  2.0  / Monthly  Póvoa de Lanhoso
# 1430    950         2   103     2  3.0  / Monthly             Braga
# 1432   1250         1   190     4  4.0  / Monthly          Barcelos
# 1433    650         2   105     4  2.0  / Monthly            Amares
#
#                         Division
# 0            Cascais e Estoril
# 1         São Domingos de Rana
# 2         São Domingos de Rana
# 3                      Olivais
# 4                      Arroios
# ...                          ...
# 1428                São Victor
# 1429   Fonte Arcada e Oliveira
# 1430                        Real
# 1432            Gamil e Midões
# 1433                   Ferreiros
#
# [906 rows x 8 columns]

# %% [markdown]
# <font face="Lucida Handwriting
# " size=6 color='#CDB79E'> Saving the result to csv file <font>

# %%
df_rent2.to_csv(r'data_frame_rent_final.csv', index = False, header=True)

# %%
rent =  pd.read_csv('data_frame_rent_final.csv')

# %%
rent
# Out:
#      Price  Prop_type  Size  Bath  Bed       Term              City  \
# 0      950          2    57     1  1.0  / Monthly           Cascais
# 1     1900          2   139     2  3.0  / Monthly           Cascais
# 2     1900          2   139     2  3.0  / Monthly           Cascais
# 3      850          2    55     1  2.0  / Monthly            Lisboa
# 4     2350          2   112     2  2.0  / Monthly            Lisboa
# ..     ...        ...   ...   ...  ...        ...               ...
# 901    825          2    94     2  2.0  / Monthly             Braga
# 902    350          1   100     1  2.0  / Monthly  Póvoa de Lanhoso
# 903    950          2   103     2  3.0  / Monthly             Braga
# 904   1250          1   190     4  4.0  / Monthly          Barcelos
# 905    650          2   105     4  2.0  / Monthly            Amares
#
#                        Division
# 0           Cascais e Estoril
# 1        São Domingos de Rana
# 2        São Domingos de Rana
# 3                     Olivais
# 4                     Arroios
# ..                          ...
# 901                São Victor
# 902   Fonte Arcada e Oliveira
# 903                        Real
# 904            Gamil e Midões
# 905                   Ferreiros
#
# [906 rows x 8 columns]
